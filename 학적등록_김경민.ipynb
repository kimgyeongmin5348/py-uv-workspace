# %%
# Out:
# Overwriting app.py

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd

st.title("학적 등록")

if "student_list" not in st.session_state:
    st.session_state.student_list = []

student_ID = st.text_input('학번을 입력하세요.')
name = st.text_input('이름을 입력하세요.')
major = st.text_input('학과를 입력하세요.')

if st.button("등록"):
    if student_ID and name and major:
        new_data = {
            "학번": student_ID,
            "이름": name,
            "전공": major
        }
        st.session_state.student_list.append(new_data)
        st.success("학적이 추가되었습니다!")
    else:
        st.warning("학번, 이름, 학과를 모두 입력해주세요.")

if st.session_state.student_list:
    st.subheader("전체 학적 목록")
    df = pd.DataFrame(st.session_state.student_list)
    st.table(df)
# Out:
# <>:74: SyntaxWarning: invalid escape sequence '\l'
# <>:74: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\User\AppData\Local\Temp\ipykernel_39368\3591500320.py:74: SyntaxWarning: invalid escape sequence '\l'
#   REGION [label='REGION|region_id (PK)\lregion_name\l'];
# 2026-07-21 21:39:45.809 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:45.815 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.549
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run d:\SK_encoa\py-uv-workspace\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-07-21 21:39:46.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.555 Session state does not function when running a script without `streamlit run`
# 2026-07-21 21:39:46.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:46.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:47.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:47.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:47.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:47.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:47.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-21 21:39:47.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
