# %% [markdown]
# ```
#   연산자 (operator) : 어떠한 기능을 수행하는 기호(+, -, *, /, %, >, <, >=, <=, ==, != ...)
#   피연산자(operand) : 연산자의 작업 대상 ( 변수, 상수, 리터널, 수식...)
#
#   연산자의 종류
#  1. 산술연산자 : +, -, *, /,//, %
#  2. 비교연산자 : >, <, >=, <=, ==, !=
#  3. 논리연산자 : and, or, not
#  4. 대입연산자 : =, +=, -=, *=, /=,...
#  5. 식별연산자 : is, is not
# ```
