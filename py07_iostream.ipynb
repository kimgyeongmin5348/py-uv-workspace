# %% [markdown]
# ## 파일 입출력
#
#
# - 파이썬 표준 함수(내장함수)에는 파일과 관련된 처리를 하는 함수가 기본으로 제공된다.
# - 파일은 텍스트 파일과 바이너리 파일로 나뉜다.
# - 파일을 열때 open( )함수를 사용한다.
# - 파일 입출력 순서
#  ① 어플리케이션이 운영체제에게 파일 처리를 API 함수를 통해 의뢰하면, 운영체제가
#    요청한 업무를 수행해 주고 그 결과를 어플리케이션에게 돌려줌.
#  ② 어플리케이션이 파일 처리 업무를 의뢰하는 과정과 각 과정에서 사용되는 파이썬
#     함수
#
#
#
#
#
#
# | 단계 | 처리 흐름 | 매칭 소스 코드 | 세부 설명 |
# |---|---|---|---|
# | ① | 파일 열기 | file = open() | open() 내장함수로 파일을 연다. |
# | ② | 파일 읽기/쓰기 | file.read() / file.write() | 얻어진 파일 객체에서 데이터를 읽고 쓴다.(read,write) |
# | ③ | 파일 닫기 | file.close() | close() 함수로 객체의 사용을 종료한다. |
#
#
#
#
# 파일객체 = open('파일경로', '파일열기모드')
#
#
# | 파일 열기 모드 | 기능 |
# |---|---|
# |w:쓰기모드|파일에 내용을 쓸|
# |a:추가모드 | 파일에 내용을 추가할때 사용 |
#
#
#
#
# 파일 읽기/쓰기 함수
#
#
# | 구분 | 함수(메서드)명 | 반환 및 특징 |
# | :---: | :--- | :--- |
# | **읽기 (Read)** | `read()` | 파일 전체 내용을 하나의 문자열로 반환 |
# | **읽기 (Read)** | `readline()` | 파일의 현재 위치에서 딱 한 줄만 반환 |
# | **읽기 (Read)** | `readlines()` | 모든 줄을 읽어 문자열 리스트로 반환 |
# | **쓰기 (Write)** | `write()` | 문자열 하나를 파일에 기록 |
# | **쓰기 (Write)** | `writelines()` | 문자열 리스트/튜플을 한 번에 기록 |

# %%
# %mkdir source
# Out:
# ���� ���͸� �Ǵ� ���� source��(��) �̹� �ֽ��ϴ�.

# %%
fwrite = open('source/sample.txt','w')
fwrite.write('데이터 저장')
fwrite.close()

# %%
fwrite = open('source/sample.txt','w')  # 파일을 쓰기로 오픈한다.(엡데이트 : 'w'사용)
for i in range(1,6):
    data = '{}번째 줄입니다.\n'.format(i)
    fwrite.write(data)

fwrite.close()

# %%
fread = open('source/sample.txt','r')
line = fread.read() # read()는 파일의 모든 데이터를 읽어온다.
print(line)
print(type(line))   # <class 'str'>
fread.close()   # 파일 닫기 해줘야 한다!
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
#
# <class 'str'>

# %%
fread = open('source/sample.txt','r')
count = 0
while True:
    line = fread.readline() # readline은 한줄씩 읽어온다.
    

    if not line:    # 파일에서 더 이상 읽어올 내용이 없으면
        break   # while 종료
    print(line,end= '')
    count +=1

fread.close()
print(f'총 {count} 줄입니다.')
# Out:
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.
# 총 5 줄입니다.

# %%
fread = open('source/sample.txt','r')
line = fread.readlines() # readlines()는 파일에서 한 라인씩 읽어와서 list에 저장한 후 리턴한다.
print(type(line))
print(line)
fread.close()

for data in line:
    print(data,end='')
# Out:
# <class 'list'>
# ['1번째 줄입니다.\n', '2번째 줄입니다.\n', '3번째 줄입니다.\n', '4번째 줄입니다.\n', '5번째 줄입니다.\n']
# 1번째 줄입니다.
# 2번째 줄입니다.
# 3번째 줄입니다.
# 4번째 줄입니다.
# 5번째 줄입니다.

# %%
with open('source/sample.txt','w') as f:    # 파일에 새로운 내용을 추가 한다.
    for i in range(6,11):
        data = '{}번째 줄입니다.\n'.format(i)
        f.write(data)
        # print(data,end='')

# %%
with open('source/sample.txt') as f:
    while True:
        line = f.readline()
        

        if not line:
            break
        
        print(line,end='')
# Out:
# 6번째 줄입니다.
# 7번째 줄입니다.
# 8번째 줄입니다.
# 9번째 줄입니다.
# 10번째 줄입니다.

# %%
with open('source/sample.txt','w') as f:
    f.writelines(['apple', 'banana', 'lemon']) # Iterable한 값을 저장할때 사용

    # f.write(['apple', 'banana', 'lemon']) <-- write()는 str일때만 가능

# %%
with open('source/sample.txt','r') as f:
    # print(f.readline()) # str형식으로 읽고
    print(f.readlines())    # 리스트로 읽음
# Out:
# ['applebananalemon']

# %% [markdown]
# ## 주요 입출력(직렬화/데이터 저장) 모듈
# 직렬화(Serialization)란?
# - 파이썬의 객체(리스트, 딕셔너리, 클래스 등)를 파일로 저장하거나     네트워크로 전송할 수 있는 바이트/텍스트 형태로 변환하는 작업입니다.
# - 입출력 모듈 종류
# ①pickle: 텍스트 상태의 데이터가 아닌 파이썬 객체 자체를 파일로 저장하는 모듈
# ②json : 타 언어 호환성이 가장 뛰어난 텍스트 기반 모듈
# ③csv : 엑셀과 연동되는 표 형태 데이터 전용 모듈
# ④marshal : 파이썬 내부 바이트코드를 위한 고속 모듈
# ⑤shelve : 파일 자체를 딕셔너리처럼 쓰는 영구 저장소 모듈
# ⑥configparser : 설정 파일(INI)을 관리하는 전용 모듈
#
#
#
#
#
#
# | 모듈명 | 데이터 형태 | 타 언어 호환 | 보안성 | 주요 용도 |
# | :---: | :---: | :---: | :---: | :--- |
# | **pickle** | 바이너리 | 불가능 (파이썬 전용) | ⚠️ 취약 (경고) | 파이썬 복잡한 객체 완벽 저장 |
# | **json** | 텍스트 (문자열) | **우수 (글로벌 표준)** | 안전함 | 웹 API 통신, 일반 데이터 저장 |
# | **shelve** | 바이너리 | 불가능 (파이썬 전용) | ⚠️ 취약 (경고) | 대용량 key-value 로컬 데이터베이스 |
# | **csv** | 텍스트 (문자열) | **우수 (엑셀 연동)** | 안전함 | 표 형태 데이터, 데이터베이스 내보내기 |

# %% [markdown]
# ### pickle 모듈이란?
# - 파이썬 객체 구조를 그대로 바이트 스트림으로 변환(직렬화)하고, 이를 다시 파이썬 객체로 복원(역직렬화)하는 파이썬 고유의 표준 모듈
#
#
# - 핵심 함수
#  ①pickle.dump(obj, file): 객체를 바이너리 파일에 저장
#  ②pickle.load(file): 바이너리 파일로 부터 객체를 복원
#
#
# - ⚠치명적인 보안 경고 (중요)
# ①pickle은 신뢰할 수 없는 데이터(인터넷에서 다운로드한 파일 등)를 역직렬화할 때    악성 코드가 자동으로 실행될 수 있는 심각한 보안 취약점이 있다.
# ②따라서 외부 통신용 데이터 저장에는 절대로 사용을 지양해야 한다.

# %%
import pickle   # byte 단위로 저장

# %%
with open('source/sample.txt','wb') as f:   
    pickle.dump(['apple','banana','lemon'],f)   # dump(저장할 데이터, 파일)

# %%
with open('source/sample.txt','r') as f:   
    print(pickle.load(f))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[300], line 2
#       1 with open('source/sample.txt','r') as f:
# ----> 2     print(pickle.load(f))
#       3
#
# File <frozen codecs>:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 'Could not get source, probably due dynamically evaluated source code.'
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %%
with open('source/sample.txt','wb') as f:   
    pickle.dump(['apple',20,True],f)   # dump(저장할 데이터, 파일)

# %%
with open('source/sample.txt','rb') as f:
    print(pickle.load(f))
# Out:
# ['apple', 20, True]

# %% [markdown]
# source/jumsu.txt파일의 내용을 읽어와서 오름차순으로 정렬을 한 후 출력하는 프로그램을 구현

# %%
index =[]

with open('source/jumsu.txt') as f:
   line = f.read()

data=line.split(',')

for i in data:
    index.append(i)

for i in range(len(index)):
    for j in range(len(index) - 1):
        if index[j] > index[j+1]:
            temp = index[j]
            index[j] = index[j+1]
            index[j+1] = temp



print(index)

# 강사님 풀이
# with open('source/jumsu.txt') as f:
#     line = f.read()

# data = line.split(',')
# print(data)
# data.sort()
# print(data)
# Out:
# ['10', '40', '50', '60', '90']

# %% [markdown]
# ###  json (웹 표준 및 안전한 대체재)
# - json 모듈?
#   ① 텍스트 기반(문자열)으로 저장되어 사람이 직접 읽고 수정할 수 있음
#   ②자바스크립트, 자바, C++ 등 다른 프로그래밍 언어와 데이터 교환 시 표준으로 사용
#   ③텍스트 형식이므로 pickle과 같은 악성 코드 실행 위험이 없어 매우 안전함
# - 핵심 암기 공식: 's' = String (문자열)
#   - s가 없는 함수 (dump, load)   →  '파일(File)' 객체를 직접 읽고 쓸 때 사용
#   - s가 있는 함수 (dumps, loads) →  '문자열(String)' 데이터를 직접 다룰 때 사용
#
#
# - 4대 함수 기능 요약
#   ① json.dump()  : 파이썬 객체를 'JSON 파일'로 저장 (입력)
#   ② json.dumps() : 파이썬 객체를 'JSON 문자열'로 변환 (변환)
#   ③ json.load()  : 'JSON 파일'을 파이썬 객체로 읽어옴 (출력)
#   ④ json.loads() : 'JSON 문자열'을 파이썬 객체로 변환 (복원)
#
#
# - json.dump() / dumps() 핵심 옵션
#  - 파이썬 객체를 JSON 형식으로 변환할 때 가독성, 정렬, 한글 처리, 데이터 예외 등을
#     세밀하게 제어하기 위해 인자(Argument) 값을 추가할 수 있다.
#     ① indent : 들여쓰기 공백 수 지정 (가독성 향상)
#     ② ensure_ascii : 아스키(ASCII) 변환 여부 (한글 깨짐 방지)
#     ③ sort_keys : 딕셔너리 키(Key) 정렬 여부 (데이터 정렬)
#     ④ separators : 데이터 구분 기호 변경 (용량 압축)
#     ⑤ default : 직렬화 불가능한 객체의 처리 함수 지정 (에러 방지)

# %% [markdown]
# ***문자열 전용 함수 (dumps / loads) 예제***
# - 파일 입출력(I/O) 과정 없이, 메모리 상에서 파일 형식을 가진 문자열로만 주고받을 때 사용합니다. (웹 통신, API 전송 등)

# %%
import json

data = {'name':'kim', 'age':25}

json_string = json.dumps(data)  # dict -> str 으로 변환 되었다.

print(type(json_string))    # 딕셔너리 모양이지만 실제로는 문자열 이다.
print(json_string)
# Out:
# <class 'str'>
# {"name": "kim", "age": 25}

# %%
json_dict = json.loads(json_string)

print(type(json_dict))
print(json_dict)
# Out:
# <class 'dict'>
# {'name': 'kim', 'age': 25}

# %%
import json

from datetime import datetime

data ={
    'c_group' : '인공지능팀',
    'a_id' : 1004,
    'd_data' : [1,2,3],
    'b_data' : datetime.now()
}

#datatime 객체를 문자열로 변환해 주는 함수
def json_default_handler(obj):
    if isinstance(obj, datetime):
        return obj.strftime('%Y-%m-%d %H:%M:%S')

#모든 옵션을 집약하여 호출
result = json.dumps(
    data,
    indent=4,
    ensure_ascii=False,  # True로 했을때 : \uc778\uacf5\uc9c0\ub2a5\ud300 [기본으로 True 되어있다.]
    sort_keys=True,
    default= json_default_handler
)

print(result)
# Out:
# {
#     "a_id": 1004,
#     "b_data": "2026-07-15 15:40:42",
#     "c_group": "인공지능팀",
#     "d_data": [
#         1,
#         2,
#         3
#     ]
# }

# %% [markdown]
# ■ 콘솔 출력 내용 (Console Output)
#   {
#       "a_id": 1004,
#       "b_date": "2026-07-15 15:14:49",
#       "c_group": "인공지능팀"
#   }
#
#   ※ 특이사항 분석
#   - 키가 알파벳 순서(a_id -> b_date -> c_group)로 자동 정렬되었습니다.
#   - 한글 '인공지능팀'이 깨지지 않고 정상 표기됩니다.
#   - 변환 불가였던 datetime 객체가 지정한 문자열 포맷으로 안전하게 출력되었습니다.
#
#
# {
#     "a_id": 1004,
#     "b_data": "2026-07-15 15:16:39",
#     "c_group": "인공지능팀",
#     "d_data": [
#         1,
#         2,
#         3
#     ]
# }

# %%
header = ['학번', '이름','전공']
students = [
    ['202601', '홍길동', '컴퓨터공함'],
    ['202602', '이순신', '데이터사이언스'],
    ['202603', '유관순', '인공지능학']
]

import json

result_list = []

for i in students:
    result_dict = dict(zip(header,i))
    result_list.append(result_dict)



result = json.dumps(
    result_list,
    indent=4,
    ensure_ascii=False,
    sort_keys=True
)
print(result)
# Out:
# [
#     {
#         "이름": "홍길동",
#         "전공": "컴퓨터공함",
#         "학번": "202601"
#     },
#     {
#         "이름": "이순신",
#         "전공": "데이터사이언스",
#         "학번": "202602"
#     },
#     {
#         "이름": "유관순",
#         "전공": "인공지능학",
#         "학번": "202603"
#     }
# ]

# %%
with open('source/students.json','w') as  f:
    json.dump(result,f,ensure_ascii=False,sort_keys=True)

# %%
with open('source/students.json','r') as  f:
    load_data = json.load(f)

print(load_data)
# Out:
# [
#     {
#         "이름": "홍길동",
#         "전공": "컴퓨터공함",
#         "학번": "202601"
#     },
#     {
#         "이름": "이순신",
#         "전공": "데이터사이언스",
#         "학번": "202602"
#     },
#     {
#         "이름": "유관순",
#         "전공": "인공지능학",
#         "학번": "202603"
#     }
# ]

# %%
import csv

header = ['학번', '이름','전공']
students = [
    ['202601', '홍길동', '컴퓨터공함'],
    ['202602', '이순신', '데이터사이언스'],
    ['202603', '유관순', '인공지능학']
]

# 저장을 할때 새로운 라인이 추가되지 않도록 newline=''을 저장한다.
with open('source/records.csv','w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(students)


with open('source/records.csv','r') as f:
    reader = csv.reader(f)
    for i in reader:
        # print(i)
        print(f'student_id : {i[0]} | name : {i[1]} | major : {i[2]}')
# Out:
# student_id : 학번 | name : 이름 | major : 전공
# student_id : 202601 | name : 홍길동 | major : 컴퓨터공함
# student_id : 202602 | name : 이순신 | major : 데이터사이언스
# student_id : 202603 | name : 유관순 | major : 인공지능학
